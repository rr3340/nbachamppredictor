# %%
import pandas as pd

# %%
advanced_league_results = pd.read_csv("advanced_league_results.csv") #Import the csv file.

# %%
advanced_league_results = advanced_league_results[["Year", "Rk", "Team", "W", "L", "MOV", "ORtg", "DRtg", "NRtg", "FTr", "3PAr", "TS%", "eFG%", "TOV%", "ORB%", "DRB%", "FT/FGA",  "Won Championship", "Rounds Played"]] #Organize the columns that are needed

# %%
advanced_league_results = advanced_league_results.dropna(subset=["Year", "Rk", "Team", "W", "L", "MOV", "ORtg", "DRtg", "NRtg", "FTr", "3PAr", "TS%", "eFG%", "TOV%", "ORB%", "DRB%", "FT/FGA",  "Won Championship", "Rounds Played"]) #Drop all na's just incase, in order to prepare data for machine learning

# %%
yearAndChampion = {
    1984: 'Boston Celtics',
    1985: 'Los Angeles Lakers',
    1986: 'Boston Celtics',
    1987: 'Los Angeles Lakers',
    1988: 'Los Angeles Lakers',
    1989: 'Detroit Pistons',
    1990: 'Detroit Pistons',
    1991: 'Chicago Bulls',
    1992: 'Chicago Bulls',
    1993: 'Chicago Bulls',
    1994: 'Houston Rockets',
    1995: 'Houston Rockets',
    1996: 'Chicago Bulls',
    1997: 'Chicago Bulls',
    1998: 'Chicago Bulls',
    1999: 'San Antonio Spurs',
    2000: 'Los Angeles Lakers',
    2001: 'Los Angeles Lakers',
    2002: 'Los Angeles Lakers',
    2003: 'San Antonio Spurs',
    2004: 'Detroit Pistons',
    2005: 'San Antonio Spurs',
    2006: 'Miami Heat',
    2007: 'San Antonio Spurs',
    2008: 'Boston Celtics',
    2009: 'Los Angeles Lakers',
    2010: 'Los Angeles Lakers',
    2011: 'Dallas Mavericks',
    2012: 'Miami Heat',
    2013: 'Miami Heat',
    2014: 'San Antonio Spurs',
    2015: 'Golden State Warriors',
    2016: 'Cleveland Cavaliers',
    2017: 'Golden State Warriors',
    2018: 'Golden State Warriors',
    2019: 'Toronto Raptors',
    2020: 'Los Angeles Lakers',
    2021: 'Milwaukee Bucks',
    2022: 'Golden State Warriors',
    2023: 'Denver Nuggets'
}

for i in yearAndChampion:#Use a dict to assign the winner of each championship per year.
        advanced_league_results.loc[((advanced_league_results['Year'] == i) & (advanced_league_results['Team'] == yearAndChampion[i])), 'Won Championship'] = 1

# %%
playoffs = {
1984: ['Boston Celtics4','Los Angeles Lakers4','Milwaukee Bucks3','Phoenix Suns3',
       'New York Knicks2','New Jersey Nets2','Dallas Mavericks2','Utah Jazz2',
       'Washington Bullets1','Detroit Pistons1','Philadelphia 76ers1','Atlanta Hawks1'
       ,'Kansas City Kings1','Seattle SuperSonics1','Portland Trailblazers1','Denver Nuggets1'],

1985: ['Los Angeles Lakers4','Boston Celtics4','Denver Nuggets3','Philadelphia 76ers3',
       'Detroit Pistons2','Milwaukee Bucks2','Portland Trailblazers2','Utah Jazz2','Houston Rockets1',
       'San Antonio Spurs1','Dallas Mavericks1','Phoenix Suns1','Chicago Bulls1','Washington Wizards1',
       'New Jersey Nets1','Cleveland Cavaliers1'],

1986: ['Boston Celtics4','Houston Rockets4','Milwaukee Bucks3','Los Angeles Lakers3',
       'Atlanta Hawks2','Philadelphia 76ers2','Dallas Mavericks2','Denver Nuggets2','Sacramento Kings1','Trailblazers1',
       'Utah Jazz1','San Antonio Spurs1','New Jersey Nets1','Washington Wizards1','Detroit Pistons1','Chicago Bulls1'],

1987: ['Los Angeles Lakers4','Boston Celtics4','Seattle SuperSonics3','Detroit Pistons3','Milwaukee Bucks2','Atlanta Hawks2',
       'Golden State Warriors2','Houston Rockets2','Dallas Mavericks1','Portland Trailblazers1','Utah Jazz1','Denver Nuggets1',
       'Indiana Pacers1','Washington Wizards1','Philadelphia 76ers1','Chicago Bulls1'],

1988: ['Los Angeles Lakers4','Detroit Pistons4','Boston Celtics3','Dallas Mavericks3',
       'Utah Jazz2','Denver Nuggets2','Chicago Bulls2','Atlanta Hawks2','New York Knicks1',
       'Milwaukee Bucks1','Cleveland Cavaliers1','Washington Wizards1','San Antonio Spurs1','Portland Trailblazers1','Houston Rockets1','Seattle SuperSonics1'],

1989: ['Detroit Pistons4','Los Angeles Lakers4','Chicago Bulls3','Phoenix Suns3',
       'Milwaukee Bucks2','New York Knicks2','Seattle SuperSonics2','Golden State Warriors2',
       'Boston Celtics1','Atlanta Hawks1','Cleveland Cavaliers1','Philadelphia 76ers1',
       'Portland Trailblazers1','Houston Rockets1','Denver Nuggets1','Utah Jazz1'],

1990: ['Detroit Pistons4','Portland Trailblazers4','Phoenix Suns3','Chicago Bulls3','New York Knicks2',
       'Philadelphia 76ers2','Los Angeles Lakers2','San Antonio Spurs2','Denver Nuggets1','Dallas Mavericks1',
       'Utah Jazz1','Houston Rockets1','Cleveland Cavaliers1','Milwaukee Bucks1','Boston Celtics1','Indiana Pacers1'],

1991: ['Chicago Bulls4','Los Angeles Lakers4','Portland Trailblazers3','Detroit Pistons3',
       'Philadelphia 76ers2','Boston Celtics2','Utah Jazz2','Golden State Warriors2','New York Knicks1','Milwaukee Bucks1',
       'Atlanta Hawks1','Indiana Pacers1','Seattle SuperSonics1','Phoenix Suns1','Houston Rockets1','San Antonio Spurs1'],

1992: ['Chicago Bulls4','Portland Trailblazers4','Cleveland Cavaliers3','Utah Jazz3','New York Knicks2',
       'Boston Celtics2','Phoenix Suns2','Seattle SuperSonics2','Miami Heat1','Detroit Pistons1',
       'New Jersey Nets1','Indiana Pacers1','Los Angeles Lakers1','San Antonio Spurs1','Golden State Warriors1','Los Angeles Clippers1'],

1993: ['Chicago Bulls4','Phoenix Suns4','New York Knicks3','Seattle SuperSonics3','Charlotte Hornets2','Cleveland Cavaliers2',
       'San Antonio Spurs2','Houston Rockets2','Indiana Pacers1','Boston Celtics1','New Jersey Nets1',
       'Atlanta Hawks1','Los Angeles Lakers1','Portland Trailblazers1','Utah Jazz1','Los Angeles Clippers1'],

1994: ['Houston Rockets4','New York Knicks4','Indiana Pacers3','Utah Jazz3','Atlanta Hawks2','Chicago Bulls2',
       'Denver Nuggets2','Phoenix Suns2','Miami Heat1','Orlando Magic1','Cleveland Cavaliers1',
       'New Jersey Nets1','Seattle SuperSonics1','San Antonio Spurs1','Golden State Warriors1','Portland Trailblazers1'],

1995: ['Houston Rockets4','Orlando Magic4','Indiana Pacers3','San Antonio Spurs3','Chicago Bulls2',
       'New York Knicks2','Los Angeles Lakers2','Phoenix Suns2','Boston Celtics1','Charlotte Hornets1','Cleveland Cavaliers1',
       'Atlanta Hawks1','Denver Nuggets1','Seattle SuperSonics1','Utah Jazz1','Portland Trailblazers1'],

1996: ['Chicago Bulls4','Seattle SuperSonics4','Orlando Magic3','Utah Jazz3','New York Knicks2','Atlanta Hawks2',
       'Houston Rockets2','San Antonio Spurs2','Miami Heat1','Cleveland Cavaliers1',
       'Indiana Pacers1','Detroit Pistons1','Sacramento Kings1','Los Angeles Lakers1','Portland Trailblazers1','Phoenix Suns1'],

1997: ['Chicago Bulls4','Utah Jazz4','Miami Heat3','Houston Rockets3','Atlanta Hawks2','New York Knicks2','Los Angeles Lakers2',
       'Seattle SuperSonics2','Washington Wizards1','Detroit Pistons1','Charlotte Hornets1','Orlando Magic1','Los Angeles Clippers1',
       'Portland Trailblazers1','Minnesota Timberwolves1','Phoenix Suns1'],

1998: ['Chicago Bulls4','Utah Jazz4','Indiana Pacers3','Los Angeles Lakers3','Charlotte Hornets2','New York Knicks2',
       'San Antonio Spurs2','Seattle SuperSonics2','New Jersey Nets1','Atlanta Hawks1','Cleveland Cavaliers1',
       'Miami Heat1','Houston Rockets1','Phoenix Suns1','Portland Trailblazers1','Minnesota Timberwolves1'],

1999: ['San Antonio Spurs4','New York Knicks4','Indiana Pacers3','Portland Trailblazers3','Atlanta Hawks2','Philadelphia 76ers2',
       'Los Angeles Lakers2','Utah Jazz2','Miami Heat1','Detroit Pistons1','Orlando Magic1','Milwaukee Bucks1','Minnesota Timberwolves1',
       'Houston Rockets1','Sacramento Kings1','Phoenix Suns1'],

2000: ['Los Angeles Lakers4','Indiana Pacers4','New York Knicks3','Portland Trailblazers3',
       'Philadelphia 76ers2','Miami Heat2','Phoenix Suns2','Utah Jazz2','Milwaukee Bucks1','Charlotte Hornets1',
       'Toronto Raptors1','Detroit Pistons1','Sacramento Kings1','San Antonio Spurs1','Minnesota Timberwolves1','Seattle SuperSonics1'],

2001: ['Los Angeles Lakers4','Philadelphia 76ers4','Milwaukee Bucks3','San Antonio Spurs3','Toronto Raptors2','Charlotte Hornets2',
       'Dallas Mavericks2','Sacramento Kings2','Indiana Pacers1','New York Knicks1','Miami Heat1','Orlando Magic1','Minnesota Timberwolves1',
       'Utah Jazz1','Phoenix Suns1','Portland Trailblazers1'],

2002: ['Los Angeles Lakers4','New Jersey Nets4','Sacramento Kings3','Boston Celtics3','Charlotte Hornets2','Detroit Pistons2',
       'Dallas Mavericks2','San Antonio Spurs2','Indiana Pacers1','Orlando Magic1','Philadelphia 76ers1','Toronto Raptors1','Utah Jazz1',
       'Minnesota Timberwolves1','Portland Trailblazers1','Seattle SuperSonics1'],

2003: ['San Antonio Spurs4', 'New Jersey Nets4', 'Dallas Mavericks3', 'Detroit Pistons3', 
        'Philadelphia 76ers2', 'Boston Celtics2', 'Los Angeles Lakers2', 'Sacramento Kings2',
       'Orlando Magic1', 'New Orleans Hornets1', 'Indiana Pacers1', 'Milwaukee Bucks1' , 
        'Phoenix Suns1', 'Minnesota Timberwolves1', 'Portland Trailblazers1', 'Utah Jazz1'],

2004: ['Detroit Pistons4', 'Los Angeles Lakers4', 'Indiana Pacers3', 'Minnesota Timberwolves3', 
        'San Antonio Spurs2', 'Sacramento Kings2', 'New Jersey Nets2', 'Miami Heat2',
       'Boston Celtics1', 'New Orleans Hornets1', 'Milwaukee Bucks1', 'New York Knicks1', 
        'Denver Nuggets1', 'Dallas Mavericks1', 'Memphis Grizzlies1', 'Houston Rockets1'],

2005: ['San Antonio Spurs4', 'Detroit Pistons4', 'Miami Heat3', 'Phoenix Suns3', 
        'Washington Wizards2', 'Indiana Pacers2', 'Dallas Mavericks2', 'Seattle SuperSonics2',
       'New Jersey Nets1', 'Chicago Bulls1', 'Boston Celtics1', 'Philadelphia 76ers1', 
        'Denver Nuggets1', 'Sacramento Kings1', 'Houston Rockets1', 'Memphis Grizzlies1'],

2006: ['Miami Heat4', 'Dallas Mavericks4', 'Detroit Pistons3', 'Phoenix Suns3', 
        'Cleveland Cavaliers2', 'New Jersey Nets2', 'San Antonio Spurs2', 'Los Angeles Clippers2',
       'Milwaukee Bucks1', 'Washington Wizards1', 'Indiana Pacers1', 'Chicago Bulls1', 
        'Sacramento Kings1', 'Memphis Grizzlies1', 'Denver Nuggets1', 'Los Angeles Lakers1'],

2007: ['San Antonio Spurs4', 'Cleveland Cavaliers4', 'Utah Jazz3', 'Detroit Pistons3', 
        'Chicago Bulls2', 'New Jersey Nets2', 'Golden State Warriors2', 'Phoenix Suns2',
       'Orlando Magic1', 'Miami Heat1', 'Toronto Raptors1', 'Washginton Wizards1', 
        'Dallas Mavericks1', 'Houston Rockets1', 'Denver Nuggets1', 'Los Angeles Lakers1'],

2008: ['Boston Celtics4', 'Los Angeles Lakers4', 'Detroit Pistons3', 'San Antonio Spurs3', 
        'Cleveland Cavaliers2', 'Orlando Magic2', 'Utah Jazz2', 'New Orleans Hornets2',
       'Atlanta Hawks1', 'Washington Wizards1', 'Toronto Raptors1', 'Philadelphia 76ers1', 'Denver Nuggets1', 
        'Houston Rockets1', 'Phoenix Suns1', 'Dallas Mavericks1'],

2009: ['Los Angeles Lakers4', 'Orlando Magic4', 'Cleveland Cavaliers3', 'Denver Nuggets3', 'Atlanta Hawks2', 'Boston Celtics2', 
        'Houston Rockets2', 'Dallas Mavericks2',
       'New Orleans Hornets1', 'San Antonio Spurs1', 'Portland Trailblazers1', 'Utah Jazz1', 'Chicago Bulls1', 
        'Philadelphia 76ers1', 'Miami Heat1', 'Detroit Pistons1'],

2010: ['Los Angeles Lakers4', 'Boston Celtics4', 'Orlando Magic3', 'Phoenix Suns3', 
        'San Antonio Spurs2', 'Utah Jazz2', 'Atlanta Hawks2', 'Cleveland Cavaliers2',
       'Chicago Bulls1', 'Miami Heat1', 'Milwaukee Bucks1', 'Charlotte Bobcats1', 'Oklahoma City Thunder1',
        'Denver Nuggets1', 'Portland Trailblazers1', 'Dallas Mavericks1'],

2011: ['Dallas Mavericks4', 'Miami Heat4', 'Oklahoma City Thunder3', 'Chicago Bulls3', 
        'Atlanta Hawks2', 'Boston Celtics2', 'Memphis Grizzlies2', 'Los Angeles Lakers2',
       'Indiana Pacers1', 'Orlando Magic1', 'New York Knicks1', 'Philadelphia 76ers1', 'San Antonio Spurs1', 
        'Denver Nuggets1', 'Portland Trailblazers1', 'New Orleans Pelicans1'],

2012: ['Miami Heat4', 'Oklahoma City Thunder4', 'San Antonio Spurs3', 'Boston Celtics3', 'Philadelphia 76ers2', 
        'Indiana Pacers2', 'Los Angeles Clippers2', 'Los Angeles Lakers2',
       'Chicago Bulls1', 'Atlanta Hawks1', 'Orlando Magic1', 'New York Knicks1', 'Utah Jazz1', 
        'Memphis Grizzlies1', 'Denver Nuggets1', 'Dallas Mavericks1'],

2013: ['Miami Heat4', 'San Antonio Spurs4', 'Indiana Pacers3', 'Memphis Grizzlies3', 'Oklahoma City Thunder2', 'Golden State Warriors2', 
        'New York Knicks2', 'Chicago Bulls2', 'Milwaukee Bucks1', 'Brooklyn Nets1', 'Atlanta Hawks1', 
        'Boston Celtics1' , 'Houston Rockets1', 'Los Angeles Clippers1', 'Denver Nuggets1', 'Los Angeles Lakers1'],

2014: ['San Antonio Spurs4', 'Miami Heat4', 'Indiana Pacers3', 'Oklahoma City Thunder3', 'Portland Trailblazers2', 'Los Angeles Clippers2', 
        'Brooklyn Nets2', 'Washington Wizards2', 'Atlanta Hawks1', 'Chicago Bulls1', 
        'Toronto Raptors1', 'Charlotte Hornets1', 'Dallas Mavericks1', 'Houston Rockets1', 'Golden State Warriors1', 'Memphis Grizzlies1'],

2015: ['Golden State Warriors4', 'Cleveland Cavaliers4', 'Atlanta Hawks3', 'Houston Rockets3', 
        'Memphis Grizzlies2', 'Los Angeles Clippers2', 'Chicago Bulls2', 'Washington Wizards2',
       'Brooklyn Nets1', 'Toronto Raptors1', 'Milwaukee Bucks1', 'Boston Celtics1', 'New Orleans Pelicans1', 'Portland Trailblazers1', 
        'San Antonio Spurs1', 'Dallas Mavericks1'],

2016: ['Cleveland Cavaliers4', 'Golden State Warriors4', 'Oklahoma City Thunder3', 'Toronto Raptors3', 'Atlanta Hawks2', 
        'Miami Heat2', 'Portland Trailblazers2', 'San Antonio Spurs2',
       'Detroit Pistons1', 'Boston Celtics1', 'Charlotte Hornets1', 'Indiana Pacers1', 'Houston Rockets1', 'Los Angeles Clippers1', 
        'Dallas Mavericks1', 'Memphis Grizzlies1'],

2017: ['Golden State Warriors4', 'Cleveland Cavaliers4', 'Boston Celtics3', 'San Antonio Spurs3', 
        'Houston Rockets2', 'Utah Jazz2', 'Toronto Raptors2', 'Washington Wizards2',
       'Chicago Bulls1', 'Atlanta Hawks1', 'Milwaukee Bucks1', 'Indiana Pacers1',
        'Portland Trailblazers1', 'Los Angeles Clippers1', 'Memphis Grizzlies1', 'Oklahoma City Thunder1'],

2018: ['Golden State Warriors4', 'Cleveland Cavaliers4', 'Boston Celtics3', 'Houston Rockets3', 
        'New Orleans Pelicans2', 'Utah Jazz2', 'Philadelphia 76ers2', 'Toronto Raptors2',
       'Washington Wizards1', 'Indiana Pacers1', 'Miami Heat1', 'Milwaukee Bucks1', 'Minnesota Timberwolves1', 
        'Oklahoma City Thunder1', 'Portland Trailblazers1', 'San Antonio Spurs1'],

2019: ['Toronto Raptors4', 'Golden State Warriors4', 'Milwaukee Bucks3', 'Portland Trailblazers3', 'Denver Nuggets2', 
        'Houston Rockets2', 'Philadelphia 76ers2', 'Boston Celtics2', 'San Antonio Spurs1', 'Oklahoma City Thunder1', 
        'Utah Jazz1', 'Los Angeles Clippers1', 'Orlando Magic1', 'Brooklyn Nets1', 'Indiana Pacers1', 'Detroit Pistons1'],

2020: ['Los Angeles Lakers4', 'Miami Heat4', 'Boston Celtics3', 'Denver Nuggets3', 'Los Angeles Clippers2', 
        'Houston Rockets2', 'Toronto Raptors2', 'Milwaukee Bucks2',
       'Orlando Magic1', 'Indiana Pacers1', 'Philadelphia 76ers1', 'Brooklyn Nets1', 'Portland Trailblazers1', 
        'Oklahoma City Thunder1', 'Utah Jazz1', 'Dallas Mavericks1'],

2021: ['Milwaukee Bucks4', 'Phoenix Suns4', 'Atlanta Hawks3', 'Los Angeles Clippers3', 'Utah Jazz2', 'Denver Nuggets2', 
        'Brooklyn Nets2', 'Philadelphia 76ers2', 'Los Angeles Lakers1', 'Portland Trailblazers1', 'Dallas Mavericks1',
       'Memphis Grizzlies1', 'Boston Celtics1', 'Miami Heat1', 'New York Knicks1', 'Washington Wizards1'],

2022: ['Golden State Warriors4', 'Boston Celtics4', 'Dallas Mavericks3', 'Miami Heat3', 
        'Philadelphia 76ers2', 'Phoenix Suns2', 'Milwaukee Bucks2', 'Memphis Grizzlies2', 'New Orleans Pelicans1', 'Utah Jazz1',
       'Denver Nuggets1', 'Minnesota Timberwolves1', 'Brooklyn Nets1', 'Chicago Bulls1', 'Toronto Raptors1', 'Atlanta Hawks1'],

2023: ['Denver Nuggets4', 'Miami Heat4', 'Boston Celtics3', 'Los Angeles Lakers3', 
        'New York Knicks2', 'Philadelphia 76ers2', 'Phoenix Suns2', 'Golden State Warriors2', 
        'Milwaukee Bucks1', 'Cleveland Cavaliers1', 'Brooklyn Nets16', 'Atlanta Hawks1', 'Minnesota Timberwolves1', 
        'Los Angeles Clippers1', 'Sacramento Kings1', 'Memphis Grizzlies1']
}

for year, teams in playoffs.items():#Use a dict to assign how far each team had gotten during the playoffs.
    for i in teams:#Match the teams and sort the rounds played in order to submit data.
        team = i[:-1]
        rounds = int(i[-1])
        advanced_league_results.loc[(advanced_league_results['Year'] == year) & (advanced_league_results['Team'] == team), 'Rounds Played'] = rounds

# %%
advanced_league_results #Check your results
# Out:
#      Year    Rk                    Team     W     L    MOV   ORtg   DRtg  \
# 0    1994   1.0     Seattle SuperSonics  63.0  19.0   9.09  111.1  101.5
# 1    1994   2.0         New York Knicks  57.0  25.0   6.99  105.7   98.2
# 2    1994   3.0       San Antonio Spurs  55.0  27.0   5.26  110.4  104.6
# 3    1994   4.0           Atlanta Hawks  57.0  25.0   5.27  107.2  101.7
# 4    1994   5.0            Phoenix Suns  56.0  26.0   4.84  111.7  106.8
# ..    ...   ...                     ...   ...   ...    ...    ...    ...
# 909  2023  26.0  Portland Trail Blazers  33.0  49.0  -4.01  114.8  118.8
# 910  2023  27.0       Charlotte Hornets  27.0  55.0  -6.24  109.2  115.3
# 911  2023  28.0         Houston Rockets  22.0  60.0  -7.85  111.4  119.3
# 912  2023  29.0         Detroit Pistons  17.0  65.0  -8.22  110.7  118.9
# 913  2023  30.0       San Antonio Spurs  22.0  60.0 -10.04  110.2  120.0
#
#      NRtg    FTr   3PAr    TS%   eFG%  TOV%  ORB%  DRB%  FT/FGA  \
# ...

# %%
advanced_league_results.to_csv("advanced_league_results.csv") #Import to a csv of the same name
